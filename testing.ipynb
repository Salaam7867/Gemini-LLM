# %%
import os
from dotenv import load_dotenv

load_dotenv()
print(os.getenv("OPENAI_API_KEY"))
# Out:
# sk-your_actual_key_here

# %%
pwd
# Out:
# 'C:\\Users\\mohda\\primeai\\GenAI\\PROJECTS\\Gemini-LLM'
